# %% [markdown]
# ### OOP Assignment

# %%
import numpy as np

class Game:
    def __init__(self):
        pass

    @staticmethod
    def car_game():
        start_state = False
        print("Your car is stopped, what do you want to do?")
        while True:
            order = input("> ").upper()
            if order == "HELP":
                print("start - to start the car\nstop - to stop the car\nquit - to Exit")
            elif order == "START":
                if not start_state:
                    print("Car started..Ready to go!")
                    start_state = True
                else:
                    print("Car is already working!")
            elif order == "STOP":
                if start_state:
                    print("Car stopped.")
                    start_state = False
                else:
                    print("Car is already stopped!")
            elif order == "QUIT":
                break
            else:
                print("Sorry, I don't understand that")


    @staticmethod
    def math_game():
        answer=""
        while answer != "n":
            n = int(input("Enter a number:"))
            i = 1
            while i <= 10:
                print(f"{n}*{i} = {i*n}")
                i += 1
            answer = input("Do you want to play again? (Y/N)").lower()
        else:
            pass


    @staticmethod
    def rock_game():
        playercounter = pccunter = 0
        while True:
            user_choice = input("Enter rock, paper or scesors: ").lower()
            list1=["rock","paper","scesors"]
            pc_choice = np.random.choice(list1)
            print("I choose: ",pc_choice)
            if pc_choice == user_choice:
                print("Draw\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "rock" and pc_choice == "paper":
                pccunter +=1
                print("PC wins\n"f"ME: {pccunter} , YOU:{playercounter}")
            elif user_choice == "rock" and pc_choice == "scesors":
                playercounter +=1
                print("you win\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "paper" and pc_choice == "rock":
                playercounter +=1
                print("you win\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "paper" and pc_choice == "scesors":
                pccunter +=1
                print("PC wins\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "scesors" and pc_choice == "rock":
                pccunter+=1
                print("PC wins\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "scesors" and pc_choice == "paper":
                playercounter +=1
                print("you win\n"f"ME:{pccunter} , YOU:{playercounter}")
            elif user_choice == "quit":
                break
            else :
                print("Please reEnter choice")

# %%
print("Enter a game you want to play,\n\tCar: for the car game.\n\tMath: for a math game.\n\tRock: for a rock paper scissor game.\n\tQuit: to quit")

while True:
    choice = input("> ").lower()
    if choice =="car":
        x = Game()
        x.car_game()
        print(x.car_game())
    elif choice =="math":
        x = Game()
        x.math_game()
        print(x.math_game())
    elif choice =="rock":
        x = Game()
        x.rock_game()
        print(x.rock_game())
    elif choice == "quit":
        break
    else:
        print("Sorry, I don't understand that.\nPlease re-enter a game.")
